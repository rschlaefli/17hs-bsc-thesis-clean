# %% [markdown]
# This notebook simply duplicates the LSTM_FUTURE.py script, running the first configuration in the tunings array.

# %%
import sys
import paths
from itertools import chain

from TRMM import TRMM
from ERA import ERA
from ModelHelpers import ModelHelpers
from ModelERAv3 import ModelERAv3
# Out:
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# --- CONSTANTS ---
YEARS = range(1979, 2018)
YEARS_TRAIN = range(1979, 2010)
YEARS_DEV = range(2010, 2013)  # or none to use random validation data
YEARS_TEST = range(2013, 2018)
PREDICT_ON = '{}-05-22' # this is actually not used anymore, but needed due to backwards compatibility with the API

# --- PARAMETERS ---

# the tuning to actually train
INDEX = 0

# should early stopping be enabled?
# training will stop if val_loss increased for more than PATIENCE times in a row
# enabled if >0
PATIENCE = 0

VERSION = 'Ex-template'

# should evaluate early based on cache?
EVALUATE = None

# list of hyperparameter tunings to try
TUNINGS = [
    { # 0 (E32)
        'aggregation_resolution': None,
        'config_build': {
            'batch_norm': True,
            'conv_activation': 'relu',
            'conv_dropout': [0.0, 0.0],
            'conv_filters': [16, 16],
            'conv_kernels': [3, 3],
            'conv_pooling': [0, 0, 2],
            'conv_strides': [1, 1],
            'conv_kernel_regularizer': ('L2', 0.0015),
            'conv_recurrent_regularizer': ('L2', 0.0015),
            'dense_dropout': [0.75, 0.75],
            'dense_nodes': [1024, 1024],
            'dense_activation': 'relu',
            'dense_kernel_regularizer': ('L2', 0.00075),
            'learning_rate': 0.01,
            'loss': 'mean_squared_error',
            'lstm_filters': [16, 16, 16],
            'lstm_kernels': [3, 3, 3],
            'lstm_strides': [1, 1, 1],
            'lstm_activation': 'tanh',
            'lstm_dropout': [0.3, 0.3, 0.3],
            'lstm_recurrent_dropout': [0.2, 0.2, 0.2],
            'lstm_recurrent_activation': 'hard_sigmoid',
            'optimizer': 'adam',
            'padding': 'same'
        },
        'config_fit': {
            'batch_size': 30,
            'epochs': 500,
            'lr_plateau': (0.1, 50, 0.00001),
            'patience': PATIENCE,
            'tensorboard': True,
            'validation_split': 0.2
        },
        'features': {
            'surface': ['msl'],
            1000: ['r', 't'],
            700: ['u', 'v']
        },
        'objective_onsets': True,
        'predict_on': PREDICT_ON,
        'prediction_sequence': 29,
        'prediction_offset': 1,
        'prediction_example_length': 60,
        'years': YEARS,
        'years_train': [1979, 1980, 1981, 1982, 1983, 1984, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2016],
        'years_dev': None,
        'years_test': [1985, 1995, 2003, 2004, 2005, 2014, 2015, 2017]
    }
]

# get the tuning for the current index
TUNING = TUNINGS[INDEX]

# load onset dates
onset_dates, onset_ts = ModelHelpers.load_onset_dates(version='v2', objective=True if TUNING['objective_onsets'] else False)

# prepare prediction timestamps
# generate a sequence of timestamps for train and validation (and, optionally, test)
prediction_ts = ModelHelpers.generate_prediction_ts(TUNING['predict_on'], TUNING['years'], onset_dates=onset_dates, sequence_length=TUNING['prediction_sequence'], sequence_offset=TUNING['prediction_offset'], example_length=TUNING['prediction_example_length'])

# setup a filter function
# this later prevents any data after the prediction timestamp from being fed as input
# we do this externally to allow overriding or extending the filter function if needed
def filter_fun(df, year):
    return ModelHelpers.filter_until(df, onset_ts[year])

# load the ERA dataset
features = []
print("> Loading Dataset")
for era_level in ['invariant', 'surface', 1000, 700, 200]:
    if era_level in TUNING['features']:
        dataset = ERA.load_dataset_v2(TUNING['years'], invalidate=True, level=era_level, variables=TUNING['features'][era_level], filter_fun=filter_fun, aggregation_resolution=TUNING['aggregation_resolution'])
        features = features + [dataset[feature] for feature in TUNING['features'][era_level]]

if 'trmm' in TUNING['features']:
    features = features + TRMM.load_dataset(range(1998, 2017), range(1, 6), invalidate=True, aggregation_resolution=0.75, version='v3', lon_slice=slice(61.125, 97.625), lat_slice=slice(4.125, 40.625))

# train test split
print("> Train-Test Split")
X_train, y_train, X_test, y_test, X_dev, y_dev = ModelERAv3.train_test_split(
    features,
    prediction_ts,
    onset_ts,
    years_train=TUNING['years_train'],
    years_test=TUNING['years_test'],
    years_dev=TUNING['years_dev'])

# ensure that the mean of all values is close to 0 and the normalization thus works correctly (channel-based)
assert round(X_train[:, :, :, :, 0].mean()) == 0
assert round(X_test[:, :, :, :, 0].mean()) == 0

if TUNING['years_dev']:
    assert round(X_dev[:, :, :, :, 0].mean()) == 0

# build a model based on the above tunings
for iteration in range(0, 5):
    version_id = f'{VERSION}-{iteration}_seq{TUNING["prediction_sequence"]}'
    cache_id = f'{INDEX}-{iteration}'

    print("> Training Model")
    model, config, history = ModelHelpers.run_config(
        ModelERAv3,
        TUNING,
        X_train,
        y_train,
        invalidate=True,
        evaluate=None,
        validation_data=TUNING['years_dev'],
        cache_id=cache_id,
        version=version_id)

    # evaluate the latest state of the model above
    print('Train (latest):', model.evaluate(X_train, y_train), model.predict(X_train))

    # dev_preds = model.predict(X_dev)
    # print('Dev (latest):', model.evaluate(X_dev, y_dev), dev_preds, y_dev)

    test_preds = model.predict(X_test)
    print('Test (latest):', model.evaluate(X_test, y_test), test_preds, y_test)

    # evaluate the best state of the model above
    best_instance = ModelERAv3(version=version_id, cache_id=cache_id)
    best_model = best_instance.load_model()
    print('Train (best):', best_model.evaluate(X_train, y_train), best_model.predict(X_train))

    # dev_preds_best = best_model.predict(X_dev)
    # print('Dev (best):', best_model.evaluate(X_dev, y_dev), dev_preds_best, y_dev)

    test_preds_best = best_model.predict(X_test)
    print('Test (best):', best_model.evaluate(X_test, y_test), test_preds_best, y_test)
# Out:
# > Loading Dataset
# > Processing:
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\common.py:594: FutureWarning: pd.TimeGrouper is deprecated and will be removed; Please use pd.Grouper(freq=...)
#   label=label, base=base)
# 1979 1980 1981 1982 1983
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4b3306a3302f> in <module>()
#      97 for era_level in ['invariant', 'surface', 1000, 700, 200]:
#      98     if era_level in TUNING['features']:
# ---> 99         dataset = ERA.load_dataset_v2(TUNING['years'], invalidate=True, level=era_level, variables=TUNING['features'][era_level], filter_fun=filter_fun, aggregation_resolution=TUNING['aggregation_resolution'])
#     100         features = features + [dataset[feature] for feature in TUNING['features'][era_level]]
#     101
#
# D:\Bachelorarbeit\bsc-thesis-clean\code\01_ANALYSIS\ERA.py in load_dataset_v2(years, level, variables, version, filter_fun, aggregation_resolution, invalidate, timestamp)
#     118         for year in years:
#     119             # load dataframes for all variables
# --> 120             var_dataframes = ERA.load_year_v2(year, level, variables, version=version, filter_fun=filter_fun, timestamp=timestamp)
#     121
#     122             for variable in variables:
#
# D:\Bachelorarbeit\bsc-thesis-clean\code\01_ANALYSIS\ERA.py in load_year_v2(year, level, variables, version, filter_fun, timestamp)
#      62
#      63         # resample to daily values (using mean to aggregate)
# ---> 64         data = data.resample(time='24H').mean()
#      65
#      66         # split up dataset into variable dataframes
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\common.py in wrapped_func(self, dim, keep_attrs, skipna, **kwargs)
#      52                 return self.reduce(func, dim, keep_attrs, skipna=skipna,
#      53                                    numeric_only=numeric_only, allow_lazy=True,
# ---> 54                                    **kwargs)
#      55         else:
#      56             def wrapped_func(self, dim=None, keep_attrs=False, **kwargs):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\resample.py in reduce(self, func, dim, keep_attrs, **kwargs)
#     303         """
#     304         return super(DatasetResample, self).reduce(
# --> 305             func, self._dim, keep_attrs, **kwargs)
#     306
#     307     def _interpolate(self, kind='linear'):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\groupby.py in reduce(self, func, dim, keep_attrs, **kwargs)
#     653         def reduce_dataset(ds):
#     654             return ds.reduce(func, dim, keep_attrs, **kwargs)
# --> 655         return self.apply(reduce_dataset)
#     656
#     657     def assign(self, **kwargs):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\resample.py in apply(self, func, **kwargs)
#     272         kwargs.pop('shortcut', None)  # ignore shortcut if set (for now)
#     273         applied = (func(ds, **kwargs) for ds in self._iter_grouped())
# --> 274         combined = self._combine(applied)
#     275
#     276         return combined.rename({self._resample_dim: self._dim})
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\groupby.py in _combine(self, applied)
#     614         applied_example, applied = peek_at(applied)
#     615         coord, dim, positions = self._infer_concat_args(applied_example)
# --> 616         combined = concat(applied, dim)
#     617         combined = _maybe_reorder(combined, dim, positions)
#     618         if coord is not None:
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\combine.py in concat(objs, dim, data_vars, coords, compat, positions, indexers, mode, concat_over)
#     118         raise TypeError('can only concatenate xarray Dataset and DataArray '
#     119                         'objects, got %s' % type(first_obj))
# --> 120     return f(objs, dim, data_vars, coords, compat, positions)
#     121
#     122
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\combine.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions)
#     224     dim, coord = _calc_concat_dim_coord(dim)
#     225     # Make sure we're working on a copy (we'll be loading variables)
# --> 226     datasets = [ds.copy() for ds in datasets]
#     227     datasets = align(*datasets, join='outer', copy=False, exclude=[dim])
#     228
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\combine.py in <listcomp>(.0)
#     224     dim, coord = _calc_concat_dim_coord(dim)
#     225     # Make sure we're working on a copy (we'll be loading variables)
# --> 226     datasets = [ds.copy() for ds in datasets]
#     227     datasets = align(*datasets, join='outer', copy=False, exclude=[dim])
#     228
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\resample.py in <genexpr>(.0)
#     271         """
#     272         kwargs.pop('shortcut', None)  # ignore shortcut if set (for now)
# --> 273         applied = (func(ds, **kwargs) for ds in self._iter_grouped())
#     274         combined = self._combine(applied)
#     275
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\groupby.py in reduce_dataset(ds)
#     652         """
#     653         def reduce_dataset(ds):
# --> 654             return ds.reduce(func, dim, keep_attrs, **kwargs)
#     655         return self.apply(reduce_dataset)
#     656
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\dataset.py in reduce(self, func, dim, keep_attrs, numeric_only, allow_lazy, **kwargs)
#    2480                                                      keep_attrs=keep_attrs,
#    2481                                                      allow_lazy=allow_lazy,
# -> 2482                                                      **kwargs)
#    2483             else:
#    2484                 variables[name] = var
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\variable.py in reduce(self, func, dim, axis, keep_attrs, allow_lazy, **kwargs)
#    1172         if dim is not None:
#    1173             axis = self.get_axis_num(dim)
# -> 1174         data = func(self.data if allow_lazy else self.values,
#    1175                     axis=axis, **kwargs)
#    1176
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\variable.py in data(self)
#     298             return self._data
#     299         else:
# --> 300             return self.values
#     301
#     302     @data.setter
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\variable.py in values(self)
#     394     def values(self):
#     395         """The variable's data as a numpy.ndarray"""
# --> 396         return _as_array_or_item(self._data)
#     397
#     398     @values.setter
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\variable.py in _as_array_or_item(data)
#     215     TODO: remove this (replace with np.asarray) once these issues are fixed
#     216     """
# --> 217     data = np.asarray(data)
#     218     if data.ndim == 0:
#     219         if data.dtype.kind == 'M':
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     555
#     556     def __array__(self, dtype=None):
# --> 557         self._ensure_cached()
#     558         return np.asarray(self.array, dtype=dtype)
#     559
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\indexing.py in _ensure_cached(self)
#     552     def _ensure_cached(self):
#     553         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 554             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     555
#     556     def __array__(self, dtype=None):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     536
#     537     def __array__(self, dtype=None):
# --> 538         return np.asarray(self.array, dtype=dtype)
#     539
#     540     def __getitem__(self, key):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     503     def __array__(self, dtype=None):
#     504         array = as_indexable(self.array)
# --> 505         return np.asarray(array[self.key], dtype=None)
#     506
#     507     def __getitem__(self, indexer):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\conventions.py in __getitem__(self, key)
#     387     def __getitem__(self, key):
#     388         return mask_and_scale(self.array[key], self.fill_value,
# --> 389                               self.scale_factor, self.add_offset, self._dtype)
#     390
#     391     def __repr__(self):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\conventions.py in mask_and_scale(array, fill_value, scale_factor, add_offset, dtype)
#      72     """
#      73     # by default, cast to float to ensure NaN is meaningful
# ---> 74     values = np.array(array, dtype=dtype, copy=True)
#      75     if fill_value is not None and not np.all(pd.isnull(fill_value)):
#      76         if getattr(fill_value, 'size', 1) > 1:
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     503     def __array__(self, dtype=None):
#     504         array = as_indexable(self.array)
# --> 505         return np.asarray(array[self.key], dtype=None)
#     506
#     507     def __getitem__(self, indexer):
#
# C:\tools\Anaconda3\envs\bsc-thesis\lib\site-packages\xarray\backends\netCDF4_.py in __getitem__(self, key)
#      59         with self.datastore.ensure_open(autoclose=True):
#      60             try:
# ---> 61                 data = getitem(self.get_array(), key)
#      62             except IndexError:
#      63                 # Catch IndexError in netCDF4 and return a more informative
#
# KeyboardInterrupt:
